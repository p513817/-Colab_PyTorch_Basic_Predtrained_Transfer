# %% [markdown]
# # 練習、比較兩個模型
# ###含有井字號的註解 是需要修改的位置
# ![](https://drive.google.com/uc?export=view&id=1_ifAn7dOygRKN8pvxi1jf7H3JNuub65Q)

# %% [markdown]
# 移動到你的資料夾

# %%
import os
path = ''
os.chdir(path)
print(f'Move to : {path}')

# %% [markdown]
# 導入函式庫以及導入模型
#
# ![](https://drive.google.com/uc?export=view&id=190qr1kZJvJufcJHil2wD2r6ymCbsTHRh)

# %%
import torch
import torch.nn as nn
import torchvision.models as models
from torchvision import datasets, transforms as T
from PIL import Image
import numpy as np


"""導入預訓練模型"""
#trg1_model = 
#trg2_model = 

"""將模型設為驗證模式"""
trg1_model = trg1_model.eval()
trg2_model = trg2_model.eval()

# %% [markdown]
# 輸入圖片，最後結果應該如下：
#
# Target Size: torch.Size([1, 3, 224, 224])

# %%
"""取得圖片資料"""
img_path = 'images/image.jpg'
img_pil = Image.open(img_path)

"""對圖片進行前處理"""
trans = T.Compose([
    # Resize
    # Crop
    # ToTensor
    # Normalize
    ])
img_tensor = trans(img_pil)

"""增加維度符合模型需求 (3, 224, 224) -> (1, 3, 224, 224)"""
#img_tensor = 

print(f"Target Size: {img_tensor.shape}")

# %% [markdown]
# 進行預測以及取值，參考 02_Classification 會更快得到答案

# %%
with torch.no_grad():
  """進行預測 : 注意: predict 的結果維度為 [1, 1000] ( batch_size , classes )"""
  #predict_1 = ___________
  #predict_2 = ___________

  """縮限到 [0, 1] 之間"""
  softmax = nn.Softmax(dim=0)
  predict_1 = softmax(predict_1)
  predict_2 = softmax(predict_2)

  f = open('labels/imagenet_classes.txt', 'r')
  content = f.readlines()

  """
  取得最大值 torch.max 以及 對應標籤 torch.argmax
  提示結尾有換行要替換掉 content[torch.argmax(____)].replace('\n', '')
  """
  #value_1 = 
  #label_1 = 

  #value_2 = 
  #label_2 =

# %% [markdown]
# 輸出結果如圖所示：
#
# ![](https://drive.google.com/uc?export=view&id=1ZrfcXlvfKQ_WVhKjr6ipk6Oj0MZqO8vk)

# %%
"""修改輸出文字"""


print("{:15} | {:20} | {:.5f}".format('Model1 Name', label_1, value_1 ))
print("{:15} | {:20} | {:.5f}".format('Model2 Name', label_2, value_2 ))
